# %%
# ============================================================
# PACKAGE 8.6.2 : XGBOOST AQI FORECASTING MODEL
# ============================================================

import pandas as pd
import numpy as np

from xgboost import XGBRegressor

from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score
)

import joblib


print("="*75)
print("PACKAGE 8.6.2 : XGBOOST AQI FORECASTING MODEL")
print("="*75)



# ------------------------------------------------------------
# Load Selected Features
# ------------------------------------------------------------

X_train = pd.read_csv(
    r"C:\Users\91863\Desktop\AIR QUALITY INTELLIGENCE\Forecasting Model Pipeline\Package4_Feature_Selection\X_train_selected.csv"
)

X_test = pd.read_csv(
    r"C:\Users\91863\Desktop\AIR QUALITY INTELLIGENCE\Forecasting Model Pipeline\Package4_Feature_Selection\X_test_selected.csv"
)


y_train = pd.read_csv(
    r"C:\Users\91863\Desktop\AIR QUALITY INTELLIGENCE\Forecasting Model Pipeline\Package3_Feature_Encoding\y_train.csv"
).squeeze()


y_test = pd.read_csv(
    r"C:\Users\91863\Desktop\AIR QUALITY INTELLIGENCE\Forecasting Model Pipeline\Package3_Feature_Encoding\y_test.csv"
).squeeze()



print("\nDataset Shape")

print("X_train :", X_train.shape)

print("X_test  :", X_test.shape)

print("y_train :", y_train.shape)

print("y_test  :", y_test.shape)



# ------------------------------------------------------------
# XGBoost Model
# ------------------------------------------------------------

xgb_model = XGBRegressor(

    n_estimators=500,

    learning_rate=0.03,

    max_depth=4,

    subsample=0.8,

    colsample_bytree=0.8,

    reg_lambda=5,

    objective="reg:squarederror",

    random_state=42,

    n_jobs=-1
)



print("\nTraining XGBoost Model...")


xgb_model.fit(
    X_train,
    y_train
)


print("Training Completed")



# ------------------------------------------------------------
# Prediction
# ------------------------------------------------------------

y_pred = xgb_model.predict(
    X_test
)



# ------------------------------------------------------------
# Evaluation Metrics
# ------------------------------------------------------------

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred
    )
)


mae = mean_absolute_error(
    y_test,
    y_pred
)


r2 = r2_score(
    y_test,
    y_pred
)



results = pd.DataFrame(
    {
        "Model":
        [
            "XGBoost"
        ],

        "RMSE":
        [
            round(rmse,3)
        ],

        "MAE":
        [
            round(mae,3)
        ],

        "R2":
        [
            round(r2,4)
        ]
    }
)



print("\n============================================================")
print("XGBOOST PERFORMANCE")
print("============================================================")

print(results)



# ------------------------------------------------------------
# Feature Importance
# ------------------------------------------------------------

feature_importance = pd.DataFrame(
    {
        "Feature":
        X_train.columns,

        "Importance":
        xgb_model.feature_importances_
    }
)


feature_importance = (
    feature_importance
    .sort_values(
        by="Importance",
        ascending=False
    )
)



print("\n============================================================")
print("TOP 20 XGBOOST FEATURES")
print("============================================================")


print(
    feature_importance.head(20)
)



# ------------------------------------------------------------
# Save Model
# ------------------------------------------------------------

joblib.dump(
    xgb_model,
    "XGBoost_AQI_Model.pkl"
)



# ------------------------------------------------------------
# Save Predictions
# ------------------------------------------------------------

prediction_results = pd.DataFrame(
    {
        "Actual_AQI":
        y_test,

        "Predicted_AQI":
        y_pred
    }
)


prediction_results.to_csv(
    "XGBoost_Predictions.csv",
    index=False
)



# ------------------------------------------------------------
# Save Reports
# ------------------------------------------------------------

results.to_csv(
    "XGBoost_Performance.csv",
    index=False
)


feature_importance.to_csv(
    "XGBoost_Feature_Importance.csv",
    index=False
)



print("\nSaved Files:")

print("1. XGBoost_AQI_Model.pkl")
print("2. XGBoost_Predictions.csv")
print("3. XGBoost_Performance.csv")
print("4. XGBoost_Feature_Importance.csv")


print("\nPackage 8.6.2 Completed Successfully.")
# Out:
# ===========================================================================
# PACKAGE 8.6.2 : XGBOOST AQI FORECASTING MODEL
# ===========================================================================
#
# Dataset Shape
# X_train : (1826, 30)
# X_test  : (182, 30)
# y_train : (1826,)
# y_test  : (182,)
#
# Training XGBoost Model...
# Training Completed
#
# ============================================================
# XGBOOST PERFORMANCE
# ============================================================
#      Model   RMSE     MAE      R2
# 0  XGBoost  28.18  21.586  0.8966
#
# ============================================================
# TOP 20 XGBOOST FEATURES
# ============================================================
#                 Feature  Importance
# 1                 PM2.5    0.318674
# 0                   AQI    0.278982
# 6               AQI_MA3    0.111906
# 2                  PM10    0.071176
# 12              AQI_MA7    0.032737
# 3              Rainfall    0.019998
# 10                   CO    0.013056
# 9                   NOx    0.010944
# 5             PM10_Diff    0.010374
# 23             PM25_MA3    0.009603
# 29        MODIS_AOD_MA7    0.008954
# 4       Humidity_Change    0.008108
# 15            PM25_Diff    0.007756
# 28         CO_NO2_Ratio    0.007739
# 8           Wind_Change    0.006804
# 7                   NO2    0.006643
# 19  Wind_Humidity_Index    0.006572
# 25             AQI_Lag1    0.006552
# 11                   NO    0.006272
# 14            MODIS_AOD    0.006199
#
# Saved Files:
# 1. XGBoost_AQI_Model.pkl
# 2. XGBoost_Predictions.csv
# 3. XGBoost_Performance.csv
# 4. XGBoost_Feature_Importance.csv
#
# Package 8.6.2 Completed Successfully.
